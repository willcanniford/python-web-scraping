# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re 
import codecs
import json
pattern = r"props\s+=\s+JSON.parse\(\'(.*?)\'\)"
html = requests.get("https://www.espncricinfo.com/series/19496/scorecard/1198238/england-vs-australia-1st-odi-england-v-australia-2020")
soup = BeautifulSoup(html.text, "html.parser")
scripts = soup.find_all("script")
pattern = re.compile(pattern)
#bytes_data = codecs.escape_decode(re.search(pattern, scripts[1].string).group(1))

# %%
script = [script for script in scripts if script.get('id') == '__NEXT_DATA__'][0]

# %%
pattern_str = r"type\=\"application\/json\"\>(.*?)\<\/script\>"
pattern = re.compile(pattern_str)

# %%
json.loads(script.string).keys()
# Out:
# dict_keys(['props', 'page', 'query', 'buildId', 'isFallback', 'dynamicIds', 'customServer', 'gip', 'appGip'])

# %%
json.loads(script.string)['appGip']
# Out:
# True

# %%
json.loads(script.string)['props']['pageProps']['data']['content']
# Out:
# {'innings': [{'title': 'Australia Innings',
#    'inningStatus': '',
#    'isCurrent': False,
#    'batsmen': [{'name': 'DA Warner',
#      'captain': False,
#      'isNotOut': False,
#      'runningScore': {'wickets': 1, 'runs': 13},
#      'shortText': ' b Archer',
#      'commentary': "<strong>ripper, Archer gets Warner again!</strong> 90mph/144kph, bit of late movement to beat Warner's defences, and Archer pegs back the top of his off stump! That's an absolute beauty, and England have a breakthrough. Warner's stunned facial expression tells the story - as close to unplayable as it gets",
#      'fullName': 'David Warner',
#      'href': 'https://www.espncricinfo.com/ci/content/player/219889.html',
#      'runningOver': 3.1,
#      'role': '',
#      'runs': '6',
#      'ballsFaced': '14',
#      'minutes': '15',
#      'fours': '0',
#      'sixes': '0',
#      'strikeRate': '42.85',
#      'action': 'cricinfo:cricket:game:da-warner'},
#     {'name': 'AJ Finch',
# ...
