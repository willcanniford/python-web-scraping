# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re 
import codecs
import json

url = 'https://www.bbc.co.uk/sport/cricket/scorecard/ECKO49134'
pattern = r"Morph\.toInit\.payloads\.push\(function\(\) \{ Morph\.setPayload\((,*?).*"
html = requests.get(url)
soup = BeautifulSoup(html.text, "html.parser")
scripts = soup.find_all("script")
pattern = re.compile(pattern)

# %%
script_strings = [script.string for script in scripts]

# %%
rel_string = [string for index, string in enumerate(script_strings) if string and 'Zampa' in string]

# %%
pattern_str = r"Morph\.toInit\.payloads\.push\(function\(\) \{ Morph\.setPayload\((.*)"
pattern = re.compile(pattern_str)
[re.search(pattern, text).group(1) for text in rel_string]
# Out:
# ['\'/data/bbc-morph-sport-cricket-fall-of-wicket-table-data/eventId/ECKO49134/inning/1/version/1.0.1\', {"meta":{"responseCode":200,"errorMessage":null,"headers":{"content-type":"application\\/json"}},"body":{"innings":[{"fallOfWickets":[{"score":"13","wicketNumber":"1","overs":"3.1","batterId":"PCKO4275","batterName":"Warner"},{"score":"43","wicketNumber":"2","overs":"9.1","batterId":"PCKO4780","batterName":"Finch"},{"score":"80","wicketNumber":"3","overs":"15.2","batterId":"PCKO5957","batterName":"Stoinis"},{"score":"103","wicketNumber":"4","overs":"19.2","batterId":"PCKO7596","batterName":"Labuschagne"},{"score":"123","wicketNumber":"5","overs":"23.4","batterId":"PCKO8040","batterName":"Carey"},{"score":"249","wicketNumber":"6","overs":"43.3","batterId":"PCKO4894","batterName":"Maxwell"},{"score":"259","wicketNumber":"7","overs":"45.1","batterId":"PCKO5164","batterName":"Cummins"},{"score":"273","wicketNumber":"8","overs":"46.6","batterId":"PCKO4601","batterName":"M Marsh"},{"scor
# ...
