# %% [markdown]
# # Building a class for a player
# I think that it would be very useful for us to wrap the functionality of the analysis into a class; one that we can just pass the link to the page and then we have access to all their details.

# %%
# Required imports
import requests
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt

# %% [markdown]
# ### Initial workings
# This notebook contains the workings of getting to the class, and I will save a version of the class in a `.py` file ([here](../CricketPlayer.py)) as well so we can easily import that into other notebooks later.
#
# The final version of the class is kept in that final class file linked above.

# %%
class CricketPlayer:
    def __init__(self, innings_by_innings_link):
        self.link = innings_by_innings_link
        self.soup = BeautifulSoup(requests.get(innings_by_innings_link).text, features="html.parser")
        
    def view_raw_html(self):
        return(self.soup)
    
    def raw_innings(self):
        for caption in self.soup.find_all('caption'):
            if caption.get_text() == 'Innings by innings list':
                main_table = caption.find_parent('table', {'class': 'engineTable'})
                
        columns = [header.get_text() for header in main_table.find('thead').find_all('tr')[0].find_all('th')]
        rows = []

        for innings in [row for row in main_table.find('tbody').find_all('tr')]:
            rows.append([stat.get_text() for stat in innings.find_all('td')])
            
        return(pd.DataFrame(rows, columns=columns))
    
    def innings(self):
        raw_innings = self.raw_innings()
        raw_innings['Opposition'] = raw_innings['Opposition'].str.replace('v ', '')
        raw_innings.replace('-', np.nan, inplace=True)
        raw_innings.columns = raw_innings.columns.str.lower().str.replace(' ', '_')
        raw_innings['is_out'] = raw_innings.score.astype('str').apply(lambda x: False if x in ['nan', 'DNB'] else False if '*' in x else True)
        raw_innings['did_bowl'] = raw_innings.overs.astype('str').apply(lambda x: False if x in ['nan', 'DNB'] else True)
        raw_innings['did_bat'] = raw_innings.score.str.replace('*', '').astype('str').apply(lambda x: True if x.isnumeric() else False)
        raw_innings['score'] = raw_innings['score'].str.replace('*', '')
        return(raw_innings[['inns', 'score', 'did_bat', 'is_out', 'overs', 'conc', 'wkts', 'did_bowl', 'ct', 'st', 'opposition', 'ground', 'start_date']])
    
    def batting_summary(self):
        innings = self.innings()
        total_at_bats = innings.did_bat.sum()
        dismissals = innings.is_out.sum()
        total_runs = innings.score[innings.did_bat].dropna().astype('int').sum()
        return(pd.DataFrame({'Innings': total_at_bats, 
                             'Dismissals': dismissals, 
                             'Total Runs': total_runs, 
                             'Average': round(total_runs/dismissals, 4)}, index=['Overall']))
    
    
    def rolling_average_innings(self, n_innings):
        innings = self.innings()[self.innings().did_bat].set_index('start_date').loc[:, ['score', 'is_out']]
        innings.index = pd.to_datetime(innings.index)
        innings.score = innings.score.astype('int')
        rolling_innings = innings.rolling(n_innings).sum()
        rolling_innings['average'] = rolling_innings['score'] / rolling_innings['is_out']
        return(rolling_innings)
    
    def rolling_average_matches(self, n_matches):
        matches = self.innings()[self.innings().did_bat].set_index('start_date').loc[:, ['score', 'is_out']]
        matches.score = matches.score.astype('int')
        matches.index = pd.to_datetime(matches.index)
        matches = matches.groupby('start_date').sum()
        rolling_matches = matches.rolling(n_matches).sum()
        rolling_matches['average'] = rolling_matches['score'] / rolling_matches['is_out']
        return(rolling_matches)

# %%
virat_kohli = 'http://stats.espncricinfo.com/ci/engine/player/253802.html?class=1;template=results;type=allround;view=innings'
steve_smith = 'http://stats.espncricinfo.com/ci/engine/player/267192.html?class=1;template=results;type=allround;view=innings'
kane_williamson = 'http://stats.espncricinfo.com/ci/engine/player/277906.html?class=1;template=results;type=allround;view=innings'
joe_root = 'http://stats.espncricinfo.com/ci/engine/player/303669.html?class=1;template=results;type=allround;view=innings'

# %%
root = CricketPlayer(joe_root)

# %%
innings = root.raw_innings()
innings
# Out:
#     Inns Score Overs Conc Wkts Ct St        Opposition           Ground  \
# 0      1    73     -    -    -  -  -           v India           Nagpur
# 1      2     -   1.0    5    0  0  0           v India           Nagpur
# 2      3   20*     -    -    -  -  -           v India           Nagpur
# 3      1     4     -    -    -  -  -     v New Zealand          Dunedin
# 4      2     -   5.0    8    0  0  0     v New Zealand          Dunedin
# 5      3     0     -    -    -  -  -     v New Zealand          Dunedin
# 6      1    10     -    -    -  -  -     v New Zealand       Wellington
# 7      2     -   1.0    6    0  0  0     v New Zealand       Wellington
# 8      3     -   2.0   12    0  0  0     v New Zealand       Wellington
# 9      1     -   2.0    5    0  0  0     v New Zealand         Auckland
# 10     2    45     -    -    -  -  -     v New Zealand         Auckland
# 11     3     -   DNB    -    -  1  0     v New Zealand         Auckland
# 12     4    29     -    -    -  -  -     v New Zealand         Auckland
# 13     1    40     -    -    -  -  -     v New Zealand           Lord's
# 14     2     -   DNB    -    -  1  0     v New Zealand           Lord's
# 15     3    71     -    -    -  -  -     v New Zealand           Lord's
# 16     4     -   DNB    -    -  1  0     v New Zealand           Lord's
# 17     1   104     -    -    -  -  -     v New Zealand            Leeds
# 18     2     -   DNB    -    -  0  0     v New Zealand            Leeds
# 19     3    28     -    -    -  -  -     v New Zealand            Leeds
# 20     4     -   3.0    1    0  1  0     v New Zealand            Leeds
# 21     1    30     -    -    -  -  -       v Australia       Nottingham
# 22     2     -   DNB    -    -  1  0       v Australia       Nottingham
# 23     3     5     -    -    -  -  -       v Australia       Nottingham
# 24     4     -   2.0    6    1  0  0       v Australia       Nottingham
# 25     1     6     -    -    -  -  -       v Australia           Lord's
# 26     2     -   DNB    -    -  0  0       v Australia           Lord's
# 27     3   180     -    -    -  -  -       v Australia           Lord's
# 28     4     -   7.0    9    2  0  0       v Australia           Lord's
# 29     1     -   4.0   18    0  0  0       v Australia       Manchester
# ..   ...   ...   ...  ...  ... .. .. ..            ...              ...
# 298    2     -   DNB    -    -  2  0     v West Indies       Gros Islet
# 299    3   122     -    -    -  -  -     v West Indies       Gros Islet
# 300    4     -   DNB    -    -  1  0     v West Indies       Gros Islet
# 301    1     2     -    -    -  -  -         v Ireland           Lord's
# 302    2     -   DNB    -    -  1  0         v Ireland           Lord's
# 303    3    31     -    -    -  -  -         v Ireland           Lord's
# 304    4     -   DNB    -    -  4  0         v Ireland           Lord's
# 305    1     -   DNB    -    -  1  0       v Australia       Birmingham
# 306    2    57     -    -    -  -  -       v Australia       Birmingham
# 307    3     -  12.0   50    0  0  0       v Australia       Birmingham
# 308    4    28     -    -    -  -  -       v Australia       Birmingham
# 309    1    14     -    -    -  -  -       v Australia           Lord's
# 310    2     -   DNB    -    -  0  0       v Australia           Lord's
# 311    3     0     -    -    -  -  -       v Australia           Lord's
# 312    4     -   1.0    7    0  1  0       v Australia           Lord's
# 313    1     -   DNB    -    -  1  0       v Australia            Leeds
# 314    2     0     -    -    -  -  -       v Australia            Leeds
# 315    3     -   DNB    -    -  1  0       v Australia            Leeds
# 316    4    77     -    -    -  -  -       v Australia            Leeds
# 317    1     -   6.0   39    1  1  0       v Australia       Manchester
# 318    2    71     -    -    -  -  -       v Australia       Manchester
# 319    3     -   DNB    -    -  0  0       v Australia       Manchester
# 320    4     0     -    -    -  -  -       v Australia       Manchester
# 321    1    57     -    -    -  -  -       v Australia         The Oval
# 322    2     -   DNB    -    -  0  0       v Australia         The Oval
# 323    3    21     -    -    -  -  -       v Australia         The Oval
# 324    4     -   9.0   26    2  2  0       v Australia         The Oval
# 325    1     2     -    -    -  -  -     v New Zealand  Mount Maunganui
# 326    2     -  18.0   67    1  0  0     v New Zealand  Mount Maunganui
# 327    3    11     -    -    -  -  -     v New Zealand  Mount Maunganui
#
#       Start Date
# 0    13 Dec 2012  Test # 2066
# 1    13 Dec 2012  Test # 2066
# 2    13 Dec 2012  Test # 2066
# 3     6 Mar 2013  Test # 2077
# 4     6 Mar 2013  Test # 2077
# 5     6 Mar 2013  Test # 2077
# 6    14 Mar 2013  Test # 2080
# 7    14 Mar 2013  Test # 2080
# 8    14 Mar 2013  Test # 2080
# 9    22 Mar 2013  Test # 2084
# 10   22 Mar 2013  Test # 2084
# 11   22 Mar 2013  Test # 2084
# 12   22 Mar 2013  Test # 2084
# 13   16 May 2013  Test # 2088
# 14   16 May 2013  Test # 2088
# 15   16 May 2013  Test # 2088
# 16   16 May 2013  Test # 2088
# 17   24 May 2013  Test # 2089
# 18   24 May 2013  Test # 2089
# 19   24 May 2013  Test # 2089
# 20   24 May 2013  Test # 2089
# 21   10 Jul 2013  Test # 2090
# 22   10 Jul 2013  Test # 2090
# 23   10 Jul 2013  Test # 2090
# 24   10 Jul 2013  Test # 2090
# 25   18 Jul 2013  Test # 2091
# 26   18 Jul 2013  Test # 2091
# 27   18 Jul 2013  Test # 2091
# 28   18 Jul 2013  Test # 2091
# 29    1 Aug 2013  Test # 2092
# ..           ...          ...
# 298   9 Feb 2019  Test # 2346
# 299   9 Feb 2019  Test # 2346
# 300   9 Feb 2019  Test # 2346
# 301  24 Jul 2019  Test # 2352
# 302  24 Jul 2019  Test # 2352
# 303  24 Jul 2019  Test # 2352
# 304  24 Jul 2019  Test # 2352
# 305   1 Aug 2019  Test # 2353
# 306   1 Aug 2019  Test # 2353
# 307   1 Aug 2019  Test # 2353
# 308   1 Aug 2019  Test # 2353
# 309  14 Aug 2019  Test # 2355
# 310  14 Aug 2019  Test # 2355
# 311  14 Aug 2019  Test # 2355
# 312  14 Aug 2019  Test # 2355
# 313  22 Aug 2019  Test # 2357
# 314  22 Aug 2019  Test # 2357
# 315  22 Aug 2019  Test # 2357
# 316  22 Aug 2019  Test # 2357
# 317   4 Sep 2019  Test # 2360
# 318   4 Sep 2019  Test # 2360
# 319   4 Sep 2019  Test # 2360
# 320   4 Sep 2019  Test # 2360
# 321  12 Sep 2019  Test # 2362
# 322  12 Sep 2019  Test # 2362
# 323  12 Sep 2019  Test # 2362
# 324  12 Sep 2019  Test # 2362
# 325  21 Nov 2019  Test # 2367
# 326  21 Nov 2019  Test # 2367
# 327  21 Nov 2019  Test # 2367
#
# [328 rows x 12 columns]

# %%
# Remove 'v ' from the beginning of each opposition
innings['Opposition'] = innings['Opposition'].str.replace('v ', '')

# %%
# Remove the empty columns that are used for spacing and links on the website 
innings.drop('', axis=1, inplace = True)
innings.head()
# Out:
#   Inns Score Overs Conc Wkts Ct St   Opposition   Ground   Start Date
# 0    1    73     -    -    -  -  -        India   Nagpur  13 Dec 2012
# 1    2     -   1.0    5    0  0  0        India   Nagpur  13 Dec 2012
# 2    3   20*     -    -    -  -  -        India   Nagpur  13 Dec 2012
# 3    1     4     -    -    -  -  -  New Zealand  Dunedin   6 Mar 2013
# 4    2     -   5.0    8    0  0  0  New Zealand  Dunedin   6 Mar 2013

# %% [markdown]
# I think we want to replace the blank '-' with `np.nan` to neaten up the output.

# %%
import numpy as np
innings.replace('-', np.nan, inplace=True)

# %%
innings.head()
# Out:
#   Inns Score Overs Conc Wkts   Ct   St   Opposition   Ground   Start Date
# 0    1    73   NaN  NaN  NaN  NaN  NaN        India   Nagpur  13 Dec 2012
# 1    2   NaN   1.0    5    0    0    0        India   Nagpur  13 Dec 2012
# 2    3   20*   NaN  NaN  NaN  NaN  NaN        India   Nagpur  13 Dec 2012
# 3    1     4   NaN  NaN  NaN  NaN  NaN  New Zealand  Dunedin   6 Mar 2013
# 4    2   NaN   5.0    8    0    0    0  New Zealand  Dunedin   6 Mar 2013

# %% [markdown]
# Clean up the column names.

# %%
innings.columns = innings.columns.str.lower().str.replace(' ', '_')

# %%
innings.head()
# Out:
#   inns score overs conc wkts   ct   st   opposition   ground   start_date
# 0    1    73   NaN  NaN  NaN  NaN  NaN        India   Nagpur  13 Dec 2012
# 1    2   NaN   1.0    5    0    0    0        India   Nagpur  13 Dec 2012
# 2    3   20*   NaN  NaN  NaN  NaN  NaN        India   Nagpur  13 Dec 2012
# 3    1     4   NaN  NaN  NaN  NaN  NaN  New Zealand  Dunedin   6 Mar 2013
# 4    2   NaN   5.0    8    0    0    0  New Zealand  Dunedin   6 Mar 2013

# %% [markdown]
# It will be easier if we have a flag for working out whether the batsman got out or not.

# %%
innings['is_out'] = innings.score.astype('str').apply(lambda x: np.nan if x == 'nan' else False if '*' in x else True)

# %%
innings.head()
# Out:
#   inns score overs conc wkts   ct   st   opposition   ground   start_date  \
# 0    1    73   NaN  NaN  NaN  NaN  NaN        India   Nagpur  13 Dec 2012
# 1    2   NaN   1.0    5    0    0    0        India   Nagpur  13 Dec 2012
# 2    3   20*   NaN  NaN  NaN  NaN  NaN        India   Nagpur  13 Dec 2012
# 3    1     4   NaN  NaN  NaN  NaN  NaN  New Zealand  Dunedin   6 Mar 2013
# 4    2   NaN   5.0    8    0    0    0  New Zealand  Dunedin   6 Mar 2013
#
#   is_out
# 0   True
# 1    NaN
# 2  False
# 3   True
# 4    NaN

# %% [markdown]
# Add a flag to indicate whether the player bowled in that particular innings.

# %%
innings['did_bowl'] = innings.overs.astype('str').apply(lambda x: False if x in ['nan', 'DNB'] else True)

# %%
innings[['inns', 'score', 'is_out', 'overs', 'conc', 
         'wkts', 'did_bowl', 'ct', 'st', 'opposition', 'ground', 'start_date']].head()
# Out:
#   inns score is_out overs conc wkts  did_bowl   ct   st   opposition   ground  \
# 0    1    73   True   NaN  NaN  NaN     False  NaN  NaN        India   Nagpur
# 1    2   NaN    NaN   1.0    5    0      True    0    0        India   Nagpur
# 2    3   20*  False   NaN  NaN  NaN     False  NaN  NaN        India   Nagpur
# 3    1     4   True   NaN  NaN  NaN     False  NaN  NaN  New Zealand  Dunedin
# 4    2   NaN    NaN   5.0    8    0      True    0    0  New Zealand  Dunedin
#
#     start_date
# 0  13 Dec 2012
# 1  13 Dec 2012
# 2  13 Dec 2012
# 3   6 Mar 2013
# 4   6 Mar 2013

# %% [markdown]
# Cleaned up `raw_innings()` so that we have another function that returns a clean `pd.DataFrame`.

# %%
innings['did_bat'] = innings.score.str.replace('*', '').astype('str').apply(lambda x: True if x.isnumeric() else False)

# %% [markdown]
# We can check that this correctly filters out the 'DNB' values.

# %%
innings[innings.score == 'DNB']
# Out:
#     inns score overs conc wkts   ct   st   opposition             ground  \
# 89     4   DNB   NaN  NaN  NaN  NaN  NaN  West Indies        St George's
# 153    4   DNB   NaN  NaN  NaN  NaN  NaN    Sri Lanka  Chester-le-Street
# 226    4   DNB   NaN  NaN  NaN  NaN  NaN  West Indies             Lord's
#
#       start_date is_out  did_bowl  did_bat
# 89   21 Apr 2015   True     False    False
# 153  27 May 2016   True     False    False
# 226   7 Sep 2017   True     False    False

# %%
# Innings that he didn't bat 
root.innings()[np.invert(root.innings().did_bat)].shape
# Out:
# (167, 13)

# %%
# Innings that he did bat 
root.innings()[root.innings().did_bat].shape
# Out:
# (161, 13)

# %%
# Total shape of data
root.innings().shape
# Out:
# (328, 13)

# %%
not_outs = root.innings()[(root.innings().did_bat) & np.invert(root.innings().is_out)]

# %% [markdown]
# We can join back into the raw scraping from the website to check that our not out flag is working correctly.

# %%
root.raw_innings().iloc[not_outs.index]
# Out:
#     Inns Score Overs Conc Wkts Ct St        Opposition        Ground  \
# 2      3   20*     -    -    -  -  -           v India        Nagpur
# 32     4   13*     -    -    -  -  -       v Australia    Manchester
# 44     4   26*     -    -    -  -  -       v Australia      Brisbane
# 57     1  200*     -    -    -  -  -       v Sri Lanka        Lord's
# 66     2  154*     -    -    -  -  -           v India    Nottingham
# 80     2  149*     -    -    -  -  -           v India      The Oval
# 87     2  182*     -    -    -  -  -     v West Indies   St George's
# 113    4   38*     -    -    -  -  -       v Australia    Birmingham
# 123    4   33*     -    -    -  -  -        v Pakistan     Abu Dhabi
# 142    4    4*     -    -    -  -  -    v South Africa  Johannesburg
# 164    3   71*     -    -    -  -  -        v Pakistan    Manchester
# 243    3   58*     -    -    -  -  -       v Australia        Sydney
#
#       Start Date
# 2    13 Dec 2012  Test # 2066
# 32    1 Aug 2013  Test # 2092
# 44   21 Nov 2013  Test # 2103
# 57   12 Jun 2014  Test # 2124
# 66    9 Jul 2014  Test # 2128
# 80   15 Aug 2014  Test # 2137
# 87   21 Apr 2015  Test # 2158
# 113  29 Jul 2015  Test # 2173
# 123  13 Oct 2015  Test # 2180
# 142  14 Jan 2016  Test # 2199
# 164  22 Jul 2016  Test # 2208
# 243   4 Jan 2018  Test # 2291

# %%
root.raw_innings().iloc[root.innings()[root.innings().did_bat].index]
# Out:
#     Inns Score Overs Conc Wkts Ct St        Opposition             Ground  \
# 0      1    73     -    -    -  -  -           v India             Nagpur
# 2      3   20*     -    -    -  -  -           v India             Nagpur
# 3      1     4     -    -    -  -  -     v New Zealand            Dunedin
# 5      3     0     -    -    -  -  -     v New Zealand            Dunedin
# 6      1    10     -    -    -  -  -     v New Zealand         Wellington
# 10     2    45     -    -    -  -  -     v New Zealand           Auckland
# 12     4    29     -    -    -  -  -     v New Zealand           Auckland
# 13     1    40     -    -    -  -  -     v New Zealand             Lord's
# 15     3    71     -    -    -  -  -     v New Zealand             Lord's
# 17     1   104     -    -    -  -  -     v New Zealand              Leeds
# 19     3    28     -    -    -  -  -     v New Zealand              Leeds
# 21     1    30     -    -    -  -  -       v Australia         Nottingham
# 23     3     5     -    -    -  -  -       v Australia         Nottingham
# 25     1     6     -    -    -  -  -       v Australia             Lord's
# 27     3   180     -    -    -  -  -       v Australia             Lord's
# 30     2     8     -    -    -  -  -       v Australia         Manchester
# 32     4   13*     -    -    -  -  -       v Australia         Manchester
# 33     1    16     -    -    -  -  -       v Australia  Chester-le-Street
# 35     3     2     -    -    -  -  -       v Australia  Chester-le-Street
# 38     2    68     -    -    -  -  -       v Australia           The Oval
# 40     4    11     -    -    -  -  -       v Australia           The Oval
# 42     2     2     -    -    -  -  -       v Australia           Brisbane
# 44     4   26*     -    -    -  -  -       v Australia           Brisbane
# 46     2    15     -    -    -  -  -       v Australia           Adelaide
# 48     4    87     -    -    -  -  -       v Australia           Adelaide
# 50     2     4     -    -    -  -  -       v Australia              Perth
# 52     4    19     -    -    -  -  -       v Australia              Perth
# 53     1    24     -    -    -  -  -       v Australia          Melbourne
# 55     3    15     -    -    -  -  -       v Australia          Melbourne
# 57     1  200*     -    -    -  -  -       v Sri Lanka             Lord's
# ..   ...   ...   ...  ...  ... .. .. ..            ...                ...
# 269    1     4     -    -    -  -  -           v India        Southampton
# 271    3    48     -    -    -  -  -           v India        Southampton
# 273    1     0     -    -    -  -  -           v India           The Oval
# 275    3   125     -    -    -  -  -           v India           The Oval
# 277    1    35     -    -    -  -  -       v Sri Lanka              Galle
# 279    3     3     -    -    -  -  -       v Sri Lanka              Galle
# 281    1    14     -    -    -  -  -       v Sri Lanka          Pallekele
# 283    3   124     -    -    -  -  -       v Sri Lanka          Pallekele
# 285    1    46     -    -    -  -  -       v Sri Lanka      Colombo (SSC)
# 287    3     7     -    -    -  -  -       v Sri Lanka      Colombo (SSC)
# 290    2     4     -    -    -  -  -     v West Indies         Bridgetown
# 292    4    22     -    -    -  -  -     v West Indies         Bridgetown
# 293    1     7     -    -    -  -  -     v West Indies        North Sound
# 295    3     7     -    -    -  -  -     v West Indies        North Sound
# 297    1    15     -    -    -  -  -     v West Indies         Gros Islet
# 299    3   122     -    -    -  -  -     v West Indies         Gros Islet
# 301    1     2     -    -    -  -  -         v Ireland             Lord's
# 303    3    31     -    -    -  -  -         v Ireland             Lord's
# 306    2    57     -    -    -  -  -       v Australia         Birmingham
# 308    4    28     -    -    -  -  -       v Australia         Birmingham
# 309    1    14     -    -    -  -  -       v Australia             Lord's
# 311    3     0     -    -    -  -  -       v Australia             Lord's
# 314    2     0     -    -    -  -  -       v Australia              Leeds
# 316    4    77     -    -    -  -  -       v Australia              Leeds
# 318    2    71     -    -    -  -  -       v Australia         Manchester
# 320    4     0     -    -    -  -  -       v Australia         Manchester
# 321    1    57     -    -    -  -  -       v Australia           The Oval
# 323    3    21     -    -    -  -  -       v Australia           The Oval
# 325    1     2     -    -    -  -  -     v New Zealand    Mount Maunganui
# 327    3    11     -    -    -  -  -     v New Zealand    Mount Maunganui
#
#       Start Date
# 0    13 Dec 2012  Test # 2066
# 2    13 Dec 2012  Test # 2066
# 3     6 Mar 2013  Test # 2077
# 5     6 Mar 2013  Test # 2077
# 6    14 Mar 2013  Test # 2080
# 10   22 Mar 2013  Test # 2084
# 12   22 Mar 2013  Test # 2084
# 13   16 May 2013  Test # 2088
# 15   16 May 2013  Test # 2088
# 17   24 May 2013  Test # 2089
# 19   24 May 2013  Test # 2089
# 21   10 Jul 2013  Test # 2090
# 23   10 Jul 2013  Test # 2090
# 25   18 Jul 2013  Test # 2091
# 27   18 Jul 2013  Test # 2091
# 30    1 Aug 2013  Test # 2092
# 32    1 Aug 2013  Test # 2092
# 33    9 Aug 2013  Test # 2093
# 35    9 Aug 2013  Test # 2093
# 38   21 Aug 2013  Test # 2094
# 40   21 Aug 2013  Test # 2094
# 42   21 Nov 2013  Test # 2103
# 44   21 Nov 2013  Test # 2103
# 46    5 Dec 2013  Test # 2105
# 48    5 Dec 2013  Test # 2105
# 50   13 Dec 2013  Test # 2107
# 52   13 Dec 2013  Test # 2107
# 53   26 Dec 2013  Test # 2110
# 55   26 Dec 2013  Test # 2110
# 57   12 Jun 2014  Test # 2124
# ..           ...          ...
# 269  30 Aug 2018  Test # 2317
# 271  30 Aug 2018  Test # 2317
# 273   7 Sep 2018  Test # 2318
# 275   7 Sep 2018  Test # 2318
# 277   6 Nov 2018  Test # 2324
# 279   6 Nov 2018  Test # 2324
# 281  14 Nov 2018  Test # 2326
# 283  14 Nov 2018  Test # 2326
# 285  23 Nov 2018  Test # 2329
# 287  23 Nov 2018  Test # 2329
# 290  23 Jan 2019  Test # 2342
# 292  23 Jan 2019  Test # 2342
# 293  31 Jan 2019  Test # 2344
# 295  31 Jan 2019  Test # 2344
# 297   9 Feb 2019  Test # 2346
# 299   9 Feb 2019  Test # 2346
# 301  24 Jul 2019  Test # 2352
# 303  24 Jul 2019  Test # 2352
# 306   1 Aug 2019  Test # 2353
# 308   1 Aug 2019  Test # 2353
# 309  14 Aug 2019  Test # 2355
# 311  14 Aug 2019  Test # 2355
# 314  22 Aug 2019  Test # 2357
# 316  22 Aug 2019  Test # 2357
# 318   4 Sep 2019  Test # 2360
# 320   4 Sep 2019  Test # 2360
# 321  12 Sep 2019  Test # 2362
# 323  12 Sep 2019  Test # 2362
# 325  21 Nov 2019  Test # 2367
# 327  21 Nov 2019  Test # 2367
#
# [161 rows x 12 columns]

# %% [markdown]
# We can use the clean data, with our defined flags to generate a summary data frame for the entire innings set.

# %%
root.batting_summary()
# Out:
#          Innings  Dismissals  Total Runs  Average
# Overall      161         149        7056  47.3557

# %%
start_date_innings = root.innings().set_index('start_date')

# %%
start_date_innings.index = pd.to_datetime(start_date_innings.index)
start_date_innings.index
# Out:
# DatetimeIndex(['2012-12-13', '2012-12-13', '2012-12-13', '2013-03-06',
#                '2013-03-06', '2013-03-06', '2013-03-14', '2013-03-14',
#                '2013-03-14', '2013-03-22',
#                ...
#                '2019-09-04', '2019-09-04', '2019-09-04', '2019-09-12',
#                '2019-09-12', '2019-09-12', '2019-09-12', '2019-11-21',
#                '2019-11-21', '2019-11-21'],
#               dtype='datetime64[ns]', name='start_date', length=328, freq=None)

# %%
start_date_innings.head()
# Out:
#            inns score  did_bat  is_out overs conc wkts  did_bowl   ct   st  \
# start_date
# 2012-12-13    1    73     True    True   NaN  NaN  NaN     False  NaN  NaN
# 2012-12-13    2   NaN    False   False   1.0    5    0      True    0    0
# 2012-12-13    3    20     True   False   NaN  NaN  NaN     False  NaN  NaN
# 2013-03-06    1     4     True    True   NaN  NaN  NaN     False  NaN  NaN
# 2013-03-06    2   NaN    False   False   5.0    8    0      True    0    0
#
#              opposition   ground
# start_date
# 2012-12-13        India   Nagpur
# 2012-12-13        India   Nagpur
# 2012-12-13        India   Nagpur
# 2013-03-06  New Zealand  Dunedin
# 2013-03-06  New Zealand  Dunedin

# %% [markdown]
# Having this format will allow us to rank the innings by the match using the `start_date` index.

# %%
rolling_15 = root.rolling_average_innings(15)
rolling_15
# Out:
#             score  is_out    average
# start_date
# 2012-12-13    NaN     NaN        NaN
# 2012-12-13    NaN     NaN        NaN
# 2013-03-06    NaN     NaN        NaN
# 2013-03-06    NaN     NaN        NaN
# 2013-03-14    NaN     NaN        NaN
# 2013-03-22    NaN     NaN        NaN
# 2013-03-22    NaN     NaN        NaN
# 2013-05-16    NaN     NaN        NaN
# 2013-05-16    NaN     NaN        NaN
# 2013-05-24    NaN     NaN        NaN
# 2013-05-24    NaN     NaN        NaN
# 2013-07-10    NaN     NaN        NaN
# 2013-07-10    NaN     NaN        NaN
# 2013-07-18    NaN     NaN        NaN
# 2013-07-18  645.0    14.0  46.071429
# 2013-08-01  580.0    14.0  41.428571
# 2013-08-01  573.0    14.0  40.928571
# 2013-08-09  585.0    14.0  41.785714
# 2013-08-09  587.0    14.0  41.928571
# 2013-08-21  645.0    14.0  46.071429
# 2013-08-21  611.0    14.0  43.642857
# 2013-11-21  584.0    14.0  41.714286
# 2013-11-21  570.0    13.0  43.846154
# 2013-12-05  514.0    13.0  39.538462
# 2013-12-05  497.0    13.0  38.230769
# 2013-12-13  473.0    13.0  36.384615
# 2013-12-13  462.0    13.0  35.538462
# 2013-12-26  481.0    13.0  37.000000
# 2013-12-26  490.0    13.0  37.692308
# 2014-06-12  510.0    12.0  42.500000
# ...           ...     ...        ...
# 2018-08-30  546.0    14.0  39.000000
# 2018-08-30  511.0    14.0  36.500000
# 2018-09-07  453.0    15.0  30.200000
# 2018-09-07  578.0    15.0  38.533333
# 2018-11-06  562.0    15.0  37.466667
# 2018-11-06  528.0    15.0  35.200000
# 2018-11-14  488.0    15.0  32.533333
# 2018-11-14  608.0    15.0  40.533333
# 2018-11-23  586.0    15.0  39.066667
# 2018-11-23  548.0    15.0  36.533333
# 2019-01-23  472.0    15.0  31.466667
# 2019-01-23  480.0    15.0  32.000000
# 2019-01-31  468.0    15.0  31.200000
# 2019-01-31  459.0    15.0  30.600000
# 2019-02-09  461.0    15.0  30.733333
# 2019-02-09  579.0    15.0  38.600000
# 2019-07-24  533.0    15.0  35.533333
# 2019-07-24  564.0    15.0  37.600000
# 2019-08-01  496.0    15.0  33.066667
# 2019-08-01  489.0    15.0  32.600000
# 2019-08-14  500.0    15.0  33.333333
# 2019-08-14  486.0    15.0  32.400000
# 2019-08-22  362.0    15.0  24.133333
# 2019-08-22  393.0    15.0  26.200000
# 2019-09-04  457.0    15.0  30.466667
# 2019-09-04  453.0    15.0  30.200000
# 2019-09-12  488.0    15.0  32.533333
# 2019-09-12  502.0    15.0  33.466667
# 2019-11-21  497.0    15.0  33.133333
# 2019-11-21  493.0    15.0  32.866667
#
# [161 rows x 3 columns]

# %%
rolling_15.average.plot()
plt.show()

# %%
rolling_15_matches = root.rolling_average_matches(15)
rolling_15_matches.tail(25)
# Out:
#              score  is_out    average
# start_date
# 2017-12-14  1396.0    28.0  49.857143
# 2017-12-26  1329.0    27.0  49.222222
# 2018-01-04  1392.0    26.0  53.538462
# 2018-03-22  1350.0    26.0  51.923077
# 2018-03-30  1343.0    26.0  51.653846
# 2018-05-24  1321.0    26.0  50.807692
# 2018-06-01  1171.0    25.0  46.840000
# 2018-08-01  1179.0    25.0  47.160000
# 2018-08-09  1119.0    24.0  46.625000
# 2018-08-18  1047.0    24.0  43.625000
# 2018-08-30   963.0    25.0  38.520000
# 2018-09-07   957.0    25.0  38.280000
# 2018-11-06   994.0    26.0  38.230769
# 2018-11-14  1066.0    26.0  41.000000
# 2018-11-23  1043.0    26.0  40.115385
# 2019-01-23  1035.0    26.0  39.807692
# 2019-01-31   988.0    27.0  36.592593
# 2019-02-09   984.0    28.0  35.142857
# 2019-07-24   966.0    28.0  34.500000
# 2019-08-01   960.0    28.0  34.285714
# 2019-08-14   902.0    28.0  32.214286
# 2019-08-22   934.0    29.0  32.206897
# 2019-09-04   911.0    29.0  31.413793
# 2019-09-12   970.0    30.0  32.333333
# 2019-11-21   954.0    30.0  31.800000

# %%
first_date = min(rolling_15_matches.index)
first_date_average = min(rolling_15_matches[rolling_15_matches.score > 0].index)
starting_average = rolling_15_matches.loc[first_date_average, 'average']
max_date = max(rolling_15_matches.index)

from datetime import datetime
now = datetime.now()
captaincy_start = datetime(2017, 2, 13)

# %% [markdown]
# Visualise the performance of Root since he became the captain of England.

# %%
plt.figure(figsize=(12,6))
rolling_15_matches.average.plot(color='#706fd3', label='_nolegend_', linewidth=2)
plt.plot([first_date, first_date_average], [starting_average, starting_average], linestyle=':', color='#706fd3', label='_nolegend_', linewidth=2)
plt.title('Joe Root rolling test average (15 matches)')
plt.xlabel('Match Start Date')
plt.ylabel('Batting Average (previous 15 matches)')
# 13 February 2017
plt.axvspan(captaincy_start, now, facecolor='#ff5252', alpha=0.2, label = 'Captaincy')
plt.legend()
plt.show()
